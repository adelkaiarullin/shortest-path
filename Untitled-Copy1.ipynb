# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
mpl.rc('figure', figsize = (15,15))
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
import pandas as pd
import numpy as np
import os

DATA_DIR = "data"
salt = 'hackathon-three-cities_'
l1_nrows = 1512
l2_nrows = 1248
n_horizons = 4
y_height = 3001

# Загружаем значения высот в узлах сетки для срезов L1 и L2

all_data_l1 = np.load(os.path.join(DATA_DIR, salt+"all_data_L1.npy"))
all_data_l2 = np.load(os.path.join(DATA_DIR, salt+"all_data_L2.npy"))

assert all_data_l1.shape == (l1_nrows, y_height), "Неправильный размер all_data_L1.npy"
assert all_data_l2.shape == (l2_nrows, y_height), "Неправильный размер all_data_L2.npy"

# Загружаем горизонты

l1_horizons_train = pd.read_csv(os.path.join(DATA_DIR, salt+"L1_horizons_train.csv"))
l2_horizons_train = pd.read_csv(os.path.join(DATA_DIR, salt+"L2_horizons_train.csv"))

assert l1_horizons_train.shape == (l1_nrows, n_horizons+1)
assert l2_horizons_train.shape == (l2_nrows, n_horizons+1)

# %%
a = np.concatenate([all_data_l1.T, all_data_l2.T], axis=1)

# %%
plt.imshow(all_data_l1.T)
plt.plot(l1_horizons_train.hor_1, color='red')
plt.plot(l1_horizons_train.hor_2, color='red')
plt.plot(l1_horizons_train.hor_3, color='red')
plt.plot(l1_horizons_train.hor_4, color='red')

# %%
plt.imshow(all_data_l2.T)
plt.plot(l2_horizons_train.hor_1, color='red')
plt.plot(l2_horizons_train.hor_2, color='red')
plt.plot(l2_horizons_train.hor_3, color='red')
plt.plot(l2_horizons_train.hor_4, color='red')
plt.show()

# %%
df = pd.read_csv('data/hackathon-three-cities_L1_horizons_train.csv')

# %%
df
# Out:
#          x  hor_1  hor_2  hor_3  hor_4
# 0        0    NaN    NaN    NaN    NaN
# 1        1    NaN    NaN    NaN    NaN
# 2        2    NaN    NaN    NaN    NaN
# 3        3    NaN    NaN    NaN    NaN
# 4        4    NaN    NaN    NaN    NaN
# ...    ...    ...    ...    ...    ...
# 1507  1507    NaN    NaN    NaN    NaN
# 1508  1508    NaN    NaN    NaN    NaN
# 1509  1509    NaN    NaN    NaN    NaN
# 1510  1510    NaN    NaN    NaN    NaN
# 1511  1511    NaN    NaN    NaN    NaN
#
# [1512 rows x 5 columns]
